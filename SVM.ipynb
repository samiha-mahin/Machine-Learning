# %% [markdown]
# <a href="https://colab.research.google.com/github/samiha-mahin/Machine-Learning/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn

# %%
iris=load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df = pd.DataFrame(iris.data, columns= iris.feature_names)
df['target'] = iris.target
df.head(1)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
#
#    target
# 0       0

# %%
df[df.target==1].head(2)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
#
#     target
# 50       1
# 51       1

# %%
df[df.target==2].head(2)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
#
#      target
# 100       2
# 101       2

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df0 = df[:50]
df1 = df[50:100]
df2 = df[100:]

# %%
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.scatter(df0['sepal length (cm)'], df0['sepal width (cm)'], color="green", marker = '+')
plt.scatter(df2['sepal length (cm)'], df2['sepal width (cm)'], color="blue", marker='.')

# %%
x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=0)

# %%
len(x_test)
# Out:
# 30

# %%
len(x_train)
# Out:
# 120

# %%
model=SVC()
model.fit(x_train, y_train)
model.score(x_test, y_test)
# Out:
# 1.0
